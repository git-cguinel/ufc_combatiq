# %% [markdown]
# # Import Packages

# %%
# Packages
import pandas as pd
import numpy as np

# Pipelines
from sklearn.compose import make_column_selector
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# Preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer

# Model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pickle

# %% [markdown]
# # Import Data

# %%
# Import the CSV to fighter and fight
data = pd.read_csv('../ufc_data_raw_main/data.csv')

# %%
# Check columns and example values.
data_cols = list(data.columns)
for i in data_cols:
    print(f"{i}: {data[i][1]}")
# Out:
# R_fighter: Trevin Giles
# B_fighter: Roman Dolidze
# Referee: Herb Dean
# date: 2021-03-20
# location: Las Vegas, Nevada, USA
# Winner: Red
# title_bout: False
# weight_class: Middleweight
# B_avg_KD: 0.5
# B_avg_opp_KD: 0.0
# B_avg_SIG_STR_pct: 0.66
# B_avg_opp_SIG_STR_pct: 0.305
# B_avg_TD_pct: 0.3
# B_avg_opp_TD_pct: 0.5
# B_avg_SUB_ATT: 1.5
# B_avg_opp_SUB_ATT: 0.0
# B_avg_REV: 0.0
# B_avg_opp_REV: 0.0
# B_avg_SIG_STR_att: 65.5
# B_avg_SIG_STR_landed: 35.0
# B_avg_opp_SIG_STR_att: 50.0
# B_avg_opp_SIG_STR_landed: 16.5
# B_avg_TOTAL_STR_att: 113.5
# B_avg_TOTAL_STR_landed: 68.5
# B_avg_opp_TOTAL_STR_att: 68.5
# B_avg_opp_TOTAL_STR_landed: 29.0
# B_avg_TD_att: 2.5
# B_avg_TD_landed: 1.5
# B_avg_opp_TD_att: 0.5
# B_avg_opp_TD_landed: 0.5
# B_avg_HEAD_att: 46.0
# B_avg_HEAD_landed: 20.0
# B_avg_opp_HEAD_att: 36.0
# B_avg_opp_HEAD_landed: 7.5
# B_avg_BODY_att: 12.0
# B_avg_BODY_landed: 8.0
# B_avg_opp_BODY_att: 8.0
# B_avg_opp_BODY_landed: 3.0
# B_avg_LEG_att: 7.5
# B_avg_LEG_landed: 7.0
# B_avg_opp_LEG_att: 6.0
# B_avg_opp_LEG_landed: 6.0
# B_avg_DISTANCE_att: 58.0
# B_avg_DISTANCE_landed: 30.0
# B_avg_opp_DISTANCE_att: 48.0
# B_avg_opp_DISTANCE_landed: 15.5
# B_avg_CLINCH_att: 0.5
# B_avg_CLINCH_landed: 0.5
# B_avg_opp_CLINCH_att: 0.5
# B_avg_opp_CLINCH_landed: 0.5
# B_avg_GROUND_att: 7.0
# B_avg_GROUND_landed: 4.5
# B_avg_opp_GROUND_att: 1.5
# B_avg_opp_GROUND_landed: 0.5
# B_avg_CTRL_time(seconds): 219.5
# B_avg_opp_CTRL_time(seconds): 24.5
# B_total_time_fought(seconds): 577.5
# B_total_rounds_fought: 4
# B_total_title_bouts: 0
# B_current_win_streak: 2
# B_current_lose_streak: 0
# B_longest_win_streak: 2
# B_wins: 2
# B_losses: 0
# B_draw: 0
# B_win_by_Decision_Majority: 0
# B_win_by_Decision_Split: 1
# B_win_by_Decision_Unanimous: 0
# B_win_by_KO/TKO: 1
# B_win_by_Submission: 0
# B_win_by_TKO_Doctor_Stoppage: 0
# B_Stance: Orthodox
# B_Height_cms: 187.96
# B_Reach_cms: 193.04
# B_Weight_lbs: 205.0
# R_avg_KD: 1.03125
# R_avg_opp_KD: 0.0625
# R_avg_SIG_STR_pct: 0.576875
# R_avg_opp_SIG_STR_pct: 0.38125
# R_avg_TD_pct: 0.40625
# R_avg_opp_TD_pct: 0.11625
# R_avg_SUB_ATT: 0.25
# R_avg_opp_SUB_ATT: 1.1875
# R_avg_REV: 0.375
# R_avg_opp_REV: 0.25
# R_avg_SIG_STR_att: 77.5625
# R_avg_SIG_STR_landed: 43.15625
# R_avg_opp_SIG_STR_att: 69.15625
# R_avg_opp_SIG_STR_landed: 27.59375
# R_avg_TOTAL_STR_att: 93.125
# R_avg_TOTAL_STR_landed: 57.21875
# R_avg_opp_TOTAL_STR_att: 98.34375
# R_avg_opp_TOTAL_STR_landed: 52.46875
# R_avg_TD_att: 1.28125
# R_avg_TD_landed: 0.78125
# R_avg_opp_TD_att: 4.6875
# R_avg_opp_TD_landed: 0.4375
# R_avg_HEAD_att: 71.09375
# R_avg_HEAD_landed: 38.0625
# R_avg_opp_HEAD_att: 50.40625
# R_avg_opp_HEAD_landed: 13.34375
# R_avg_BODY_att: 4.6875
# R_avg_BODY_landed: 3.3125
# R_avg_opp_BODY_att: 9.09375
# R_avg_opp_BODY_landed: 6.15625
# R_avg_LEG_att: 1.78125
# R_avg_LEG_landed: 1.78125
# R_avg_opp_LEG_att: 9.65625
# R_avg_opp_LEG_landed: 8.09375
# R_avg_DISTANCE_att: 58.3125
# R_avg_DISTANCE_landed: 30.4375
# R_avg_opp_DISTANCE_att: 63.3125
# R_avg_opp_DISTANCE_landed: 23.125
# R_avg_CLINCH_att: 6.96875
# R_avg_CLINCH_landed: 3.65625
# R_avg_opp_CLINCH_att: 5.0
# R_avg_opp_CLINCH_landed: 4.125
# R_avg_GROUND_att: 12.28125
# R_avg_GROUND_landed: 9.0625
# R_avg_opp_GROUND_att: 0.84375
# R_avg_opp_GROUND_landed: 0.34375
# R_avg_CTRL_time(seconds): 176.15625
# R_avg_opp_CTRL_time(seconds): 154.6875
# R_total_time_fought(seconds): 747.34375
# R_total_rounds_fought: 17
# R_total_title_bouts: 0
# R_current_win_streak: 2
# R_current_lose_streak: 0
# R_longest_win_streak: 2
# R_wins: 4
# R_losses: 2
# R_draw: 0
# R_win_by_Decision_Majority: 0
# R_win_by_Decision_Split: 1
# R_win_by_Decision_Unanimous: 0
# R_win_by_KO/TKO: 3
# R_win_by_Submission: 0
# R_win_by_TKO_Doctor_Stoppage: 0
# R_Stance: Orthodox
# R_Height_cms: 182.88
# R_Reach_cms: 187.96
# R_Weight_lbs: 185.0
# B_age: 32.0
# R_age: 28.0

# %% [markdown]
# # Drop Cols and Save to CSV

# %%
# Drop uneccesary columns (r and b fighter not needed for training. Ref, date, location should contain no info).
data.drop(columns=['R_fighter','B_fighter','Referee','date','location'], inplace=True)

# Check columns and example values.
data_cols = list(data.columns)
for i in data_cols:
    print(f"{i}: {data[i][1]}")
# Out:
# Winner: Red
# title_bout: False
# weight_class: Middleweight
# B_avg_KD: 0.5
# B_avg_opp_KD: 0.0
# B_avg_SIG_STR_pct: 0.66
# B_avg_opp_SIG_STR_pct: 0.305
# B_avg_TD_pct: 0.3
# B_avg_opp_TD_pct: 0.5
# B_avg_SUB_ATT: 1.5
# B_avg_opp_SUB_ATT: 0.0
# B_avg_REV: 0.0
# B_avg_opp_REV: 0.0
# B_avg_SIG_STR_att: 65.5
# B_avg_SIG_STR_landed: 35.0
# B_avg_opp_SIG_STR_att: 50.0
# B_avg_opp_SIG_STR_landed: 16.5
# B_avg_TOTAL_STR_att: 113.5
# B_avg_TOTAL_STR_landed: 68.5
# B_avg_opp_TOTAL_STR_att: 68.5
# B_avg_opp_TOTAL_STR_landed: 29.0
# B_avg_TD_att: 2.5
# B_avg_TD_landed: 1.5
# B_avg_opp_TD_att: 0.5
# B_avg_opp_TD_landed: 0.5
# B_avg_HEAD_att: 46.0
# B_avg_HEAD_landed: 20.0
# B_avg_opp_HEAD_att: 36.0
# B_avg_opp_HEAD_landed: 7.5
# B_avg_BODY_att: 12.0
# B_avg_BODY_landed: 8.0
# B_avg_opp_BODY_att: 8.0
# B_avg_opp_BODY_landed: 3.0
# B_avg_LEG_att: 7.5
# B_avg_LEG_landed: 7.0
# B_avg_opp_LEG_att: 6.0
# B_avg_opp_LEG_landed: 6.0
# B_avg_DISTANCE_att: 58.0
# B_avg_DISTANCE_landed: 30.0
# B_avg_opp_DISTANCE_att: 48.0
# B_avg_opp_DISTANCE_landed: 15.5
# B_avg_CLINCH_att: 0.5
# B_avg_CLINCH_landed: 0.5
# B_avg_opp_CLINCH_att: 0.5
# B_avg_opp_CLINCH_landed: 0.5
# B_avg_GROUND_att: 7.0
# B_avg_GROUND_landed: 4.5
# B_avg_opp_GROUND_att: 1.5
# B_avg_opp_GROUND_landed: 0.5
# B_avg_CTRL_time(seconds): 219.5
# B_avg_opp_CTRL_time(seconds): 24.5
# B_total_time_fought(seconds): 577.5
# B_total_rounds_fought: 4
# B_total_title_bouts: 0
# B_current_win_streak: 2
# B_current_lose_streak: 0
# B_longest_win_streak: 2
# B_wins: 2
# B_losses: 0
# B_draw: 0
# B_win_by_Decision_Majority: 0
# B_win_by_Decision_Split: 1
# B_win_by_Decision_Unanimous: 0
# B_win_by_KO/TKO: 1
# B_win_by_Submission: 0
# B_win_by_TKO_Doctor_Stoppage: 0
# B_Stance: Orthodox
# B_Height_cms: 187.96
# B_Reach_cms: 193.04
# B_Weight_lbs: 205.0
# R_avg_KD: 1.03125
# R_avg_opp_KD: 0.0625
# R_avg_SIG_STR_pct: 0.576875
# R_avg_opp_SIG_STR_pct: 0.38125
# R_avg_TD_pct: 0.40625
# R_avg_opp_TD_pct: 0.11625
# R_avg_SUB_ATT: 0.25
# R_avg_opp_SUB_ATT: 1.1875
# R_avg_REV: 0.375
# R_avg_opp_REV: 0.25
# R_avg_SIG_STR_att: 77.5625
# R_avg_SIG_STR_landed: 43.15625
# R_avg_opp_SIG_STR_att: 69.15625
# R_avg_opp_SIG_STR_landed: 27.59375
# R_avg_TOTAL_STR_att: 93.125
# R_avg_TOTAL_STR_landed: 57.21875
# R_avg_opp_TOTAL_STR_att: 98.34375
# R_avg_opp_TOTAL_STR_landed: 52.46875
# R_avg_TD_att: 1.28125
# R_avg_TD_landed: 0.78125
# R_avg_opp_TD_att: 4.6875
# R_avg_opp_TD_landed: 0.4375
# R_avg_HEAD_att: 71.09375
# R_avg_HEAD_landed: 38.0625
# R_avg_opp_HEAD_att: 50.40625
# R_avg_opp_HEAD_landed: 13.34375
# R_avg_BODY_att: 4.6875
# R_avg_BODY_landed: 3.3125
# R_avg_opp_BODY_att: 9.09375
# R_avg_opp_BODY_landed: 6.15625
# R_avg_LEG_att: 1.78125
# R_avg_LEG_landed: 1.78125
# R_avg_opp_LEG_att: 9.65625
# R_avg_opp_LEG_landed: 8.09375
# R_avg_DISTANCE_att: 58.3125
# R_avg_DISTANCE_landed: 30.4375
# R_avg_opp_DISTANCE_att: 63.3125
# R_avg_opp_DISTANCE_landed: 23.125
# R_avg_CLINCH_att: 6.96875
# R_avg_CLINCH_landed: 3.65625
# R_avg_opp_CLINCH_att: 5.0
# R_avg_opp_CLINCH_landed: 4.125
# R_avg_GROUND_att: 12.28125
# R_avg_GROUND_landed: 9.0625
# R_avg_opp_GROUND_att: 0.84375
# R_avg_opp_GROUND_landed: 0.34375
# R_avg_CTRL_time(seconds): 176.15625
# R_avg_opp_CTRL_time(seconds): 154.6875
# R_total_time_fought(seconds): 747.34375
# R_total_rounds_fought: 17
# R_total_title_bouts: 0
# R_current_win_streak: 2
# R_current_lose_streak: 0
# R_longest_win_streak: 2
# R_wins: 4
# R_losses: 2
# R_draw: 0
# R_win_by_Decision_Majority: 0
# R_win_by_Decision_Split: 1
# R_win_by_Decision_Unanimous: 0
# R_win_by_KO/TKO: 3
# R_win_by_Submission: 0
# R_win_by_TKO_Doctor_Stoppage: 0
# R_Stance: Orthodox
# R_Height_cms: 182.88
# R_Reach_cms: 187.96
# R_Weight_lbs: 185.0
# B_age: 32.0
# R_age: 28.0

# %%
data.shape
# Out:
# (6012, 139)

# %%
# Save dataset to Data.CSV for use in model
data.to_csv("../data/data.csv", index=False)

# %% [markdown]
# # Imputing, Encoding, Scaling Pipeline

# %%
# Create Imputing and Scaling Pipelines
num_transformer = make_pipeline(SimpleImputer(strategy="median", 
                                              missing_values = np.nan),
                                RobustScaler())
cat_transformer = make_pipeline(SimpleImputer(strategy="constant",
                                              fill_value="unknown", 
                                              missing_values = np.nan),
                               OneHotEncoder(drop='if_binary', sparse_output=False))

# Select num_col and cat_col
num_col = make_column_selector(dtype_include=['number'])
cat_col = make_column_selector(dtype_include=['object','bool'])

# Transform the Columns
transformer = make_column_transformer(
    (num_transformer, num_col),
    (cat_transformer, cat_col),
    remainder='passthrough'
)

# %%
# Create preprocessing pipeline
preprocessor = make_pipeline(transformer)
preprocessor
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('robustscaler',
#                                                                    RobustScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x128faf250>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(fill_value='unknown',
#                                                                                  strategy='constant')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x128fad780>)]))])

# %% [markdown]
# # Base Model

# %%
# Create X and y variables
X = data.drop(columns=['Winner'])
y = data['Winner']

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.33, 
                                                    random_state=42,
                                                    stratify=y)

# Preprocess
X_train_pre = pd.DataFrame(preprocessor.fit_transform(X_train))
X_test_pre = pd.DataFrame(preprocessor.transform(X_test))

# Rename columns
X_train_pre.columns = preprocessor.get_feature_names_out()
X_test_pre.columns = preprocessor.get_feature_names_out()

# %%
model = LogisticRegression(max_iter=1000)

pipeline = make_pipeline(preprocessor,
                        model)
pipeline
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('columntransformer',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('pipeline-1',
#                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                     SimpleImputer(strategy='median')),
#                                                                                    ('robustscaler',
#                                                                                     RobustScaler())]),
#                                                                    <sklearn.compose._column_transformer.make_column_selector object at 0x128faf250>),
#                                                                   ('pipeline-2',
#                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                     SimpleImputer(fill_value='unknown',
#                                                                                                   strategy='constant')),
#                                                                                    ('onehotencoder',
#                                                                                     OneHotEncoder(drop='if_binary',
#                                                                                                   sparse_output=False))]),
#                                                                    <sklearn.compose._column_transformer.make_column_selector object at 0x128fad780>)]))])),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
# Fit Model
pipeline.fit(X_train_pre, y_train)

# Score Model
pipeline.score(X_test_pre, y_test)
# Out:
# /Users/maxmaurer/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6678427419354839
